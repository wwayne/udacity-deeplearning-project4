# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = '/input/small_vocab_en'
target_path = '/input/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of each sentence from `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    source_id_text = [[source_vocab_to_int[w] for w in s.split()] for s in source_text.split('\n')]
    target_id_text = [[target_vocab_to_int[w] for w in s.split()] + [target_vocab_to_int['<EOS>']] for s in target_text.split('\n')]

    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
#
# Return the placeholders in the following the tuple (Input, Targets, Learing Rate, Keep Probability)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    # TODO: Implement Function
    input_ = tf.placeholder(tf.int32, [None, None], 'input')
    target = tf.placeholder(tf.int32, [None, None], 'target')
    lr = tf.placeholder(tf.float32)
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    return input_, target, lr, keep_prob

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoding Input
# Implement `process_decoding_input` using TensorFlow to remove the last word id from each batch in `target_data` and concat the GO ID to the beginning of each batch.

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for dencoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    striped_target = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    prepend_go = tf.fill([batch_size, 1], target_vocab_to_int['<GO>'])
    return tf.concat([prepend_go, striped_target], axis=1)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer using [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn).

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    # TODO: Implement Function
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    cell = tf.contrib.rnn.MultiRNNCell([lstm] * num_layers)
    cell = tf.contrib.rnn.DropoutWrapper(cell, 0.7)
    
    output, final_state = tf.nn.dynamic_rnn(cell, rnn_inputs, dtype=tf.float32)
    return final_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create training logits using [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).  Apply the `output_fn` to the [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) outputs.

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    # TODO: Implement Function
    decoder_fn_train = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    outputs, final_state, final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(
        cell=dec_cell, 
        decoder_fn=decoder_fn_train, 
        inputs=dec_embed_input,
        sequence_length=sequence_length,
        scope=decoding_scope
    )
    return output_fn(outputs)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference logits using [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    # TODO: Implement Function
    decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
        output_fn=output_fn,
        encoder_state=encoder_state,
        embeddings=dec_embeddings,
        start_of_sequence_id=start_of_sequence_id,
        end_of_sequence_id=end_of_sequence_id,
        maximum_length=maximum_length,
        num_decoder_symbols=vocab_size
    )
    
    outputs, final_state, final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(
        cell=dec_cell,
        decoder_fn=decoder_fn,
        scope=decoding_scope
    )
    return outputs


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# - Create RNN cell for decoding using `rnn_size` and `num_layers`.
# - Create the output fuction using [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) to transform it's input, logits, to class logits.
# - Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` function to get the training logits.
# - Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    dec_cell = tf.contrib.rnn.MultiRNNCell([lstm] * num_layers)
    
    with tf.variable_scope('training') as dec_scope:
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, activation_fn=None)
        
        train_logits = decoding_layer_train(
            encoder_state,
            dec_cell,
            dec_embed_input,
            sequence_length,
            dec_scope,
            output_fn,
            keep_prob
        )

        dec_scope.reuse_variables()
        inf_logits = decoding_layer_infer(
            encoder_state,
            dec_cell,
            dec_embeddings,
            target_vocab_to_int['<GO>'],
            target_vocab_to_int['<EOS>'],
            sequence_length,
            vocab_size,
            dec_scope,
            output_fn,
            keep_prob
        )
        return train_logits, inf_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)`.
# - Process target data using your `process_decoding_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)`.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    enc_input = tf.contrib.layers.embed_sequence(
        input_data,
        source_vocab_size,
        enc_embedding_size
    )
    enc_layer = encoding_layer(
        enc_input,
        rnn_size,
        num_layers,
        keep_prob
    )
    
    dec_input = process_decoding_input(
        target_data, 
        target_vocab_to_int, 
        batch_size
    )
        
    dec_embed = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size], -1, 1))
    target_embed = tf.nn.embedding_lookup(dec_embed, dec_input)
    
    train_logits, inf_logits = decoding_layer(
        target_embed,
        dec_embed,
        enc_layer,
        target_vocab_size,
        sequence_length,
        rnn_size,
        num_layers,
        target_vocab_to_int,
        keep_prob
    )
    return train_logits, inf_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 1024
# RNN Size
rnn_size = 128
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 256
decoding_embedding_size = 256
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.75

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  5.874
# Epoch   0 Batch    1/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  5.796
# Epoch   0 Batch    2/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  5.682
# Epoch   0 Batch    3/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  5.564
# Epoch   0 Batch    4/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  5.437
# Epoch   0 Batch    5/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  5.253
# Epoch   0 Batch    6/134 - Train Accuracy:  0.178, Validation Accuracy:  0.178, Loss:  4.949
# Epoch   0 Batch    7/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  4.857
# Epoch   0 Batch    8/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  4.638
# Epoch   0 Batch    9/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  4.280
# Epoch   0 Batch   10/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  4.238
# Epoch   0 Batch   11/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  4.065
# Epoch   0 Batch   12/134 - Train Accuracy:  0.178, Validation Accuracy:  0.178, Loss:  3.781
# Epoch   0 Batch   13/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  3.855
# Epoch   0 Batch   14/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  3.730
# Epoch   0 Batch   15/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  3.603
# Epoch   0 Batch   16/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  3.494
# Epoch   0 Batch   17/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  3.419
# Epoch   0 Batch   18/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  3.356
# Epoch   0 Batch   19/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  3.292
# Epoch   0 Batch   20/134 - Train Accuracy:  0.177, Validation Accuracy:  0.178, Loss:  3.100
# Epoch   0 Batch   21/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  3.167
# Epoch   0 Batch   22/134 - Train Accuracy:  0.096, Validation Accuracy:  0.178, Loss:  3.310
# Epoch   0 Batch   23/134 - Train Accuracy:  0.178, Validation Accuracy:  0.178, Loss:  2.953
# Epoch   0 Batch   24/134 - Train Accuracy:  0.095, Validation Accuracy:  0.178, Loss:  3.199
# Epoch   0 Batch   25/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  3.043
# Epoch   0 Batch   26/134 - Train Accuracy:  0.097, Validation Accuracy:  0.178, Loss:  3.140
# Epoch   0 Batch   27/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.971
# Epoch   0 Batch   28/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.944
# Epoch   0 Batch   29/134 - Train Accuracy:  0.177, Validation Accuracy:  0.178, Loss:  2.806
# Epoch   0 Batch   30/134 - Train Accuracy:  0.178, Validation Accuracy:  0.178, Loss:  2.775
# Epoch   0 Batch   31/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  2.878
# Epoch   0 Batch   32/134 - Train Accuracy:  0.178, Validation Accuracy:  0.178, Loss:  2.737
# Epoch   0 Batch   33/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  2.851
# Epoch   0 Batch   34/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.820
# Epoch   0 Batch   35/134 - Train Accuracy:  0.177, Validation Accuracy:  0.178, Loss:  2.697
# Epoch   0 Batch   36/134 - Train Accuracy:  0.140, Validation Accuracy:  0.178, Loss:  2.789
# Epoch   0 Batch   37/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  2.807
# Epoch   0 Batch   38/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.777
# Epoch   0 Batch   39/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.744
# Epoch   0 Batch   40/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.735
# Epoch   0 Batch   41/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  2.712
# Epoch   0 Batch   42/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  2.742
# Epoch   0 Batch   43/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.726
# Epoch   0 Batch   44/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.698
# Epoch   0 Batch   45/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  2.674
# Epoch   0 Batch   46/134 - Train Accuracy:  0.177, Validation Accuracy:  0.178, Loss:  2.557
# Epoch   0 Batch   47/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  2.657
# Epoch   0 Batch   48/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.627
# Epoch   0 Batch   49/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.612
# Epoch   0 Batch   50/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  2.621
# Epoch   0 Batch   51/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  2.614
# Epoch   0 Batch   52/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.613
# Epoch   0 Batch   53/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  2.610
# Epoch   0 Batch   54/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  2.586
# Epoch   0 Batch   55/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.577
# Epoch   0 Batch   56/134 - Train Accuracy:  0.177, Validation Accuracy:  0.178, Loss:  2.444
# Epoch   0 Batch   57/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.538
# Epoch   0 Batch   58/134 - Train Accuracy:  0.140, Validation Accuracy:  0.178, Loss:  2.513
# Epoch   0 Batch   59/134 - Train Accuracy:  0.096, Validation Accuracy:  0.178, Loss:  2.638
# Epoch   0 Batch   60/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.496
# Epoch   0 Batch   61/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  2.500
# Epoch   0 Batch   62/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  2.468
# Epoch   0 Batch   63/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.462
# Epoch   0 Batch   64/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  2.483
# Epoch   0 Batch   65/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.447
# Epoch   0 Batch   66/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  2.428
# Epoch   0 Batch   67/134 - Train Accuracy:  0.095, Validation Accuracy:  0.178, Loss:  2.575
# Epoch   0 Batch   68/134 - Train Accuracy:  0.095, Validation Accuracy:  0.178, Loss:  2.513
# Epoch   0 Batch   69/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  2.389
# Epoch   0 Batch   70/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  2.363
# Epoch   0 Batch   71/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  2.383
# Epoch   0 Batch   72/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  2.374
# Epoch   0 Batch   73/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  2.270
# Epoch   0 Batch   74/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  2.340
# Epoch   0 Batch   75/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  2.231
# Epoch   0 Batch   76/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  2.336
# Epoch   0 Batch   77/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  2.177
# Epoch   0 Batch   78/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  2.291
# Epoch   0 Batch   79/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  2.288
# Epoch   0 Batch   80/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  2.278
# Epoch   0 Batch   81/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  2.257
# Epoch   0 Batch   82/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  2.128
# Epoch   0 Batch   83/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  2.233
# Epoch   0 Batch   84/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  2.221
# Epoch   0 Batch   85/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  2.199
# Epoch   0 Batch   86/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  2.196
# Epoch   0 Batch   87/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  2.185
# Epoch   0 Batch   88/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  2.074
# Epoch   0 Batch   89/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  2.152
# Epoch   0 Batch   90/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  2.137
# Epoch   0 Batch   91/134 - Train Accuracy:  0.246, Validation Accuracy:  0.179, Loss:  1.862
# Epoch   0 Batch   92/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  2.090
# Epoch   0 Batch   93/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  2.054
# Epoch   0 Batch   94/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  2.071
# Epoch   0 Batch   95/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  2.078
# Epoch   0 Batch   96/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  2.068
# Epoch   0 Batch   97/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  2.064
# Epoch   0 Batch   98/134 - Train Accuracy:  0.097, Validation Accuracy:  0.179, Loss:  2.147
# Epoch   0 Batch   99/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  2.026
# Epoch   0 Batch  100/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  2.018
# Epoch   0 Batch  101/134 - Train Accuracy:  0.097, Validation Accuracy:  0.179, Loss:  2.077
# Epoch   0 Batch  102/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.995
# Epoch   0 Batch  103/134 - Train Accuracy:  0.177, Validation Accuracy:  0.179, Loss:  1.895
# Epoch   0 Batch  104/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.940
# Epoch   0 Batch  105/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.922
# Epoch   0 Batch  106/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.910
# Epoch   0 Batch  107/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  1.826
# Epoch   0 Batch  108/134 - Train Accuracy:  0.097, Validation Accuracy:  0.179, Loss:  1.993
# Epoch   0 Batch  109/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  1.800
# Epoch   0 Batch  110/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.844
# Epoch   0 Batch  111/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.839
# Epoch   0 Batch  112/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.839
# Epoch   0 Batch  113/134 - Train Accuracy:  0.247, Validation Accuracy:  0.179, Loss:  1.613
# Epoch   0 Batch  114/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.825
# Epoch   0 Batch  115/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  1.903
# Epoch   0 Batch  116/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.812
# Epoch   0 Batch  117/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.787
# Epoch   0 Batch  118/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.766
# Epoch   0 Batch  119/134 - Train Accuracy:  0.214, Validation Accuracy:  0.179, Loss:  1.617
# Epoch   0 Batch  120/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  1.744
# Epoch   0 Batch  121/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.718
# Epoch   0 Batch  122/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.728
# Epoch   0 Batch  123/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.705
# Epoch   0 Batch  124/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  1.616
# Epoch   0 Batch  125/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.700
# Epoch   0 Batch  126/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.672
# Epoch   0 Batch  127/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  1.611
# Epoch   0 Batch  128/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.667
# Epoch   0 Batch  129/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.643
# Epoch   0 Batch  130/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.648
# Epoch   0 Batch  131/134 - Train Accuracy:  0.097, Validation Accuracy:  0.179, Loss:  1.698
# Epoch   0 Batch  132/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.601
# Epoch   1 Batch    0/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.611
# Epoch   1 Batch    1/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  1.663
# Epoch   1 Batch    2/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.563
# Epoch   1 Batch    3/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.557
# Epoch   1 Batch    4/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.549
# Epoch   1 Batch    5/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.555
# Epoch   1 Batch    6/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  1.461
# Epoch   1 Batch    7/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.540
# Epoch   1 Batch    8/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.503
# Epoch   1 Batch    9/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  1.431
# Epoch   1 Batch   10/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.509
# Epoch   1 Batch   11/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.489
# Epoch   1 Batch   12/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  1.410
# Epoch   1 Batch   13/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.491
# Epoch   1 Batch   14/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.460
# Epoch   1 Batch   15/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  1.457
# Epoch   1 Batch   16/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.431
# Epoch   1 Batch   17/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.437
# Epoch   1 Batch   18/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.441
# Epoch   1 Batch   19/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.407
# Epoch   1 Batch   20/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  1.352
# Epoch   1 Batch   21/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.394
# Epoch   1 Batch   22/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  1.459
# Epoch   1 Batch   23/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  1.300
# Epoch   1 Batch   24/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  1.435
# Epoch   1 Batch   25/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  1.371
# Epoch   1 Batch   26/134 - Train Accuracy:  0.098, Validation Accuracy:  0.179, Loss:  1.428
# Epoch   1 Batch   27/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.357
# Epoch   1 Batch   28/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.351
# Epoch   1 Batch   29/134 - Train Accuracy:  0.177, Validation Accuracy:  0.179, Loss:  1.276
# Epoch   1 Batch   30/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  1.277
# Epoch   1 Batch   31/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.319
# Epoch   1 Batch   32/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  1.258
# Epoch   1 Batch   33/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.324
# Epoch   1 Batch   34/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.319
# Epoch   1 Batch   35/134 - Train Accuracy:  0.177, Validation Accuracy:  0.179, Loss:  1.252
# Epoch   1 Batch   36/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.288
# Epoch   1 Batch   37/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  1.295
# Epoch   1 Batch   38/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  1.279
# Epoch   1 Batch   39/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  1.259
# Epoch   1 Batch   40/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  1.260
# Epoch   1 Batch   41/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  1.239
# Epoch   1 Batch   42/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  1.258
# Epoch   1 Batch   43/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  1.260
# Epoch   1 Batch   44/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  1.242
# Epoch   1 Batch   45/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  1.224
# Epoch   1 Batch   46/134 - Train Accuracy:  0.177, Validation Accuracy:  0.178, Loss:  1.185
# Epoch   1 Batch   47/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  1.215
# Epoch   1 Batch   48/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.208
# Epoch   1 Batch   49/134 - Train Accuracy:  0.140, Validation Accuracy:  0.178, Loss:  1.195
# Epoch   1 Batch   50/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  1.201
# Epoch   1 Batch   51/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  1.198
# Epoch   1 Batch   52/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.199
# Epoch   1 Batch   53/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  1.184
# Epoch   1 Batch   54/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  1.184
# Epoch   1 Batch   55/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.185
# Epoch   1 Batch   56/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  1.120
# Epoch   1 Batch   57/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  1.157
# Epoch   1 Batch   58/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.140
# Epoch   1 Batch   59/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  1.208
# Epoch   1 Batch   60/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.138
# Epoch   1 Batch   61/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  1.132
# Epoch   1 Batch   62/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.114
# Epoch   1 Batch   63/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.128
# Epoch   1 Batch   64/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  1.142
# Epoch   1 Batch   65/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.118
# Epoch   1 Batch   66/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.105
# Epoch   1 Batch   67/134 - Train Accuracy:  0.095, Validation Accuracy:  0.179, Loss:  1.188
# Epoch   1 Batch   68/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  1.152
# Epoch   1 Batch   69/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.095
# Epoch   1 Batch   70/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  1.077
# Epoch   1 Batch   71/134 - Train Accuracy:  0.140, Validation Accuracy:  0.178, Loss:  1.088
# Epoch   1 Batch   72/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.087
# Epoch   1 Batch   73/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  1.052
# Epoch   1 Batch   74/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  1.089
# Epoch   1 Batch   75/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  1.040
# Epoch   1 Batch   76/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.066
# Epoch   1 Batch   77/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  1.009
# Epoch   1 Batch   78/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.060
# Epoch   1 Batch   79/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  1.066
# Epoch   1 Batch   80/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.060
# Epoch   1 Batch   81/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  1.049
# Epoch   1 Batch   82/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  0.987
# Epoch   1 Batch   83/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.048
# Epoch   1 Batch   84/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.037
# Epoch   1 Batch   85/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  1.036
# Epoch   1 Batch   86/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.031
# Epoch   1 Batch   87/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.036
# Epoch   1 Batch   88/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.975
# Epoch   1 Batch   89/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.021
# Epoch   1 Batch   90/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  1.022
# Epoch   1 Batch   91/134 - Train Accuracy:  0.246, Validation Accuracy:  0.179, Loss:  0.882
# Epoch   1 Batch   92/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.999
# Epoch   1 Batch   93/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.985
# Epoch   1 Batch   94/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.985
# Epoch   1 Batch   95/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.999
# Epoch   1 Batch   96/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.999
# Epoch   1 Batch   97/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.996
# Epoch   1 Batch   98/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  1.037
# Epoch   1 Batch   99/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.986
# Epoch   1 Batch  100/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.982
# Epoch   1 Batch  101/134 - Train Accuracy:  0.097, Validation Accuracy:  0.179, Loss:  1.026
# Epoch   1 Batch  102/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.970
# Epoch   1 Batch  103/134 - Train Accuracy:  0.177, Validation Accuracy:  0.178, Loss:  0.938
# Epoch   1 Batch  104/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.950
# Epoch   1 Batch  105/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.962
# Epoch   1 Batch  106/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.948
# Epoch   1 Batch  107/134 - Train Accuracy:  0.179, Validation Accuracy:  0.178, Loss:  0.919
# Epoch   1 Batch  108/134 - Train Accuracy:  0.096, Validation Accuracy:  0.178, Loss:  0.997
# Epoch   1 Batch  109/134 - Train Accuracy:  0.178, Validation Accuracy:  0.178, Loss:  0.908
# Epoch   1 Batch  110/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.927
# Epoch   1 Batch  111/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.942
# Epoch   1 Batch  112/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.934
# Epoch   1 Batch  113/134 - Train Accuracy:  0.246, Validation Accuracy:  0.178, Loss:  0.825
# Epoch   1 Batch  114/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.933
# Epoch   1 Batch  115/134 - Train Accuracy:  0.096, Validation Accuracy:  0.178, Loss:  0.981
# Epoch   1 Batch  116/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.941
# Epoch   1 Batch  117/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.927
# Epoch   1 Batch  118/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  0.921
# Epoch   1 Batch  119/134 - Train Accuracy:  0.213, Validation Accuracy:  0.178, Loss:  0.843
# Epoch   1 Batch  120/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.919
# Epoch   1 Batch  121/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.901
# Epoch   1 Batch  122/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.919
# Epoch   1 Batch  123/134 - Train Accuracy:  0.140, Validation Accuracy:  0.178, Loss:  0.907
# Epoch   1 Batch  124/134 - Train Accuracy:  0.178, Validation Accuracy:  0.178, Loss:  0.860
# Epoch   1 Batch  125/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  0.901
# Epoch   1 Batch  126/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.901
# Epoch   1 Batch  127/134 - Train Accuracy:  0.178, Validation Accuracy:  0.178, Loss:  0.865
# Epoch   1 Batch  128/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  0.903
# Epoch   1 Batch  129/134 - Train Accuracy:  0.140, Validation Accuracy:  0.178, Loss:  0.892
# Epoch   1 Batch  130/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  0.898
# Epoch   1 Batch  131/134 - Train Accuracy:  0.097, Validation Accuracy:  0.178, Loss:  0.930
# Epoch   1 Batch  132/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.871
# Epoch   2 Batch    0/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.879
# Epoch   2 Batch    1/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.914
# Epoch   2 Batch    2/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.862
# Epoch   2 Batch    3/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.868
# Epoch   2 Batch    4/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.871
# Epoch   2 Batch    5/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.876
# Epoch   2 Batch    6/134 - Train Accuracy:  0.178, Validation Accuracy:  0.178, Loss:  0.821
# Epoch   2 Batch    7/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.860
# Epoch   2 Batch    8/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.844
# Epoch   2 Batch    9/134 - Train Accuracy:  0.179, Validation Accuracy:  0.178, Loss:  0.810
# Epoch   2 Batch   10/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.855
# Epoch   2 Batch   11/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.854
# Epoch   2 Batch   12/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.810
# Epoch   2 Batch   13/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  0.855
# Epoch   2 Batch   14/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.835
# Epoch   2 Batch   15/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.832
# Epoch   2 Batch   16/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.824
# Epoch   2 Batch   17/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.842
# Epoch   2 Batch   18/134 - Train Accuracy:  0.140, Validation Accuracy:  0.178, Loss:  0.835
# Epoch   2 Batch   19/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.824
# Epoch   2 Batch   20/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.803
# Epoch   2 Batch   21/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.828
# Epoch   2 Batch   22/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.862
# Epoch   2 Batch   23/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.772
# Epoch   2 Batch   24/134 - Train Accuracy:  0.095, Validation Accuracy:  0.178, Loss:  0.852
# Epoch   2 Batch   25/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.818
# Epoch   2 Batch   26/134 - Train Accuracy:  0.097, Validation Accuracy:  0.179, Loss:  0.857
# Epoch   2 Batch   27/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.816
# Epoch   2 Batch   28/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.820
# Epoch   2 Batch   29/134 - Train Accuracy:  0.177, Validation Accuracy:  0.178, Loss:  0.763
# Epoch   2 Batch   30/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.773
# Epoch   2 Batch   31/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  0.804
# Epoch   2 Batch   32/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.767
# Epoch   2 Batch   33/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  0.809
# Epoch   2 Batch   34/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.819
# Epoch   2 Batch   35/134 - Train Accuracy:  0.177, Validation Accuracy:  0.178, Loss:  0.775
# Epoch   2 Batch   36/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.796
# Epoch   2 Batch   37/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  0.803
# Epoch   2 Batch   38/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.788
# Epoch   2 Batch   39/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.782
# Epoch   2 Batch   40/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.782
# Epoch   2 Batch   41/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.777
# Epoch   2 Batch   42/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  0.780
# Epoch   2 Batch   43/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.789
# Epoch   2 Batch   44/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.786
# Epoch   2 Batch   45/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.764
# Epoch   2 Batch   46/134 - Train Accuracy:  0.177, Validation Accuracy:  0.178, Loss:  0.751
# Epoch   2 Batch   47/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.773
# Epoch   2 Batch   48/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.772
# Epoch   2 Batch   49/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.761
# Epoch   2 Batch   50/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.770
# Epoch   2 Batch   51/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.763
# Epoch   2 Batch   52/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.773
# Epoch   2 Batch   53/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.764
# Epoch   2 Batch   54/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.761
# Epoch   2 Batch   55/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.766
# Epoch   2 Batch   56/134 - Train Accuracy:  0.177, Validation Accuracy:  0.178, Loss:  0.728
# Epoch   2 Batch   57/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.756
# Epoch   2 Batch   58/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.745
# Epoch   2 Batch   59/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.786
# Epoch   2 Batch   60/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.744
# Epoch   2 Batch   61/134 - Train Accuracy:  0.138, Validation Accuracy:  0.178, Loss:  0.740
# Epoch   2 Batch   62/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.733
# Epoch   2 Batch   63/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.741
# Epoch   2 Batch   64/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.747
# Epoch   2 Batch   65/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.740
# Epoch   2 Batch   66/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.724
# Epoch   2 Batch   67/134 - Train Accuracy:  0.095, Validation Accuracy:  0.179, Loss:  0.793
# Epoch   2 Batch   68/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.769
# Epoch   2 Batch   69/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.730
# Epoch   2 Batch   70/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.717
# Epoch   2 Batch   71/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.723
# Epoch   2 Batch   72/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.723
# Epoch   2 Batch   73/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.702
# Epoch   2 Batch   74/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.736
# Epoch   2 Batch   75/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.699
# Epoch   2 Batch   76/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.713
# Epoch   2 Batch   77/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.687
# Epoch   2 Batch   78/134 - Train Accuracy:  0.140, Validation Accuracy:  0.178, Loss:  0.722
# Epoch   2 Batch   79/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.721
# Epoch   2 Batch   80/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.720
# Epoch   2 Batch   81/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.713
# Epoch   2 Batch   82/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.672
# Epoch   2 Batch   83/134 - Train Accuracy:  0.139, Validation Accuracy:  0.178, Loss:  0.718
# Epoch   2 Batch   84/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.711
# Epoch   2 Batch   85/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.713
# Epoch   2 Batch   86/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.707
# Epoch   2 Batch   87/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.721
# Epoch   2 Batch   88/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.670
# Epoch   2 Batch   89/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.706
# Epoch   2 Batch   90/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.707
# Epoch   2 Batch   91/134 - Train Accuracy:  0.246, Validation Accuracy:  0.179, Loss:  0.615
# Epoch   2 Batch   92/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.692
# Epoch   2 Batch   93/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.686
# Epoch   2 Batch   94/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.682
# Epoch   2 Batch   95/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.695
# Epoch   2 Batch   96/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.698
# Epoch   2 Batch   97/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.696
# Epoch   2 Batch   98/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.727
# Epoch   2 Batch   99/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.691
# Epoch   2 Batch  100/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.687
# Epoch   2 Batch  101/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.729
# Epoch   2 Batch  102/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.681
# Epoch   2 Batch  103/134 - Train Accuracy:  0.177, Validation Accuracy:  0.179, Loss:  0.664
# Epoch   2 Batch  104/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.670
# Epoch   2 Batch  105/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.689
# Epoch   2 Batch  106/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.682
# Epoch   2 Batch  107/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  0.653
# Epoch   2 Batch  108/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.712
# Epoch   2 Batch  109/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.645
# Epoch   2 Batch  110/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.666
# Epoch   2 Batch  111/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.680
# Epoch   2 Batch  112/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.668
# Epoch   2 Batch  113/134 - Train Accuracy:  0.246, Validation Accuracy:  0.179, Loss:  0.592
# Epoch   2 Batch  114/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.667
# Epoch   2 Batch  115/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.708
# Epoch   2 Batch  116/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.676
# Epoch   2 Batch  117/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.664
# Epoch   2 Batch  118/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.662
# Epoch   2 Batch  119/134 - Train Accuracy:  0.214, Validation Accuracy:  0.179, Loss:  0.606
# Epoch   2 Batch  120/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.668
# Epoch   2 Batch  121/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.656
# Epoch   2 Batch  122/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.670
# Epoch   2 Batch  123/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.658
# Epoch   2 Batch  124/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.626
# Epoch   2 Batch  125/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.659
# Epoch   2 Batch  126/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.663
# Epoch   2 Batch  127/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.635
# Epoch   2 Batch  128/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.665
# Epoch   2 Batch  129/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.654
# Epoch   2 Batch  130/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.659
# Epoch   2 Batch  131/134 - Train Accuracy:  0.097, Validation Accuracy:  0.179, Loss:  0.682
# Epoch   2 Batch  132/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.643
# Epoch   3 Batch    0/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.650
# Epoch   3 Batch    1/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.677
# Epoch   3 Batch    2/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.642
# Epoch   3 Batch    3/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.646
# Epoch   3 Batch    4/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.654
# Epoch   3 Batch    5/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.655
# Epoch   3 Batch    6/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.615
# Epoch   3 Batch    7/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.644
# Epoch   3 Batch    8/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.633
# Epoch   3 Batch    9/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  0.607
# Epoch   3 Batch   10/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.639
# Epoch   3 Batch   11/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.643
# Epoch   3 Batch   12/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.613
# Epoch   3 Batch   13/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.646
# Epoch   3 Batch   14/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.633
# Epoch   3 Batch   15/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.627
# Epoch   3 Batch   16/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.623
# Epoch   3 Batch   17/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.643
# Epoch   3 Batch   18/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.634
# Epoch   3 Batch   19/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.629
# Epoch   3 Batch   20/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.614
# Epoch   3 Batch   21/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.638
# Epoch   3 Batch   22/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.657
# Epoch   3 Batch   23/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.595
# Epoch   3 Batch   24/134 - Train Accuracy:  0.095, Validation Accuracy:  0.179, Loss:  0.653
# Epoch   3 Batch   25/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.626
# Epoch   3 Batch   26/134 - Train Accuracy:  0.097, Validation Accuracy:  0.179, Loss:  0.658
# Epoch   3 Batch   27/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.623
# Epoch   3 Batch   28/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.633
# Epoch   3 Batch   29/134 - Train Accuracy:  0.177, Validation Accuracy:  0.179, Loss:  0.585
# Epoch   3 Batch   30/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.596
# Epoch   3 Batch   31/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.621
# Epoch   3 Batch   32/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.598
# Epoch   3 Batch   33/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.627
# Epoch   3 Batch   34/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.637
# Epoch   3 Batch   35/134 - Train Accuracy:  0.177, Validation Accuracy:  0.179, Loss:  0.604
# Epoch   3 Batch   36/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.619
# Epoch   3 Batch   37/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.623
# Epoch   3 Batch   38/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.614
# Epoch   3 Batch   39/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.610
# Epoch   3 Batch   40/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.613
# Epoch   3 Batch   41/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.612
# Epoch   3 Batch   42/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.610
# Epoch   3 Batch   43/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.616
# Epoch   3 Batch   44/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.617
# Epoch   3 Batch   45/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.599
# Epoch   3 Batch   46/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.589
# Epoch   3 Batch   47/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.611
# Epoch   3 Batch   48/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.609
# Epoch   3 Batch   49/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.599
# Epoch   3 Batch   50/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.611
# Epoch   3 Batch   51/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.601
# Epoch   3 Batch   52/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.610
# Epoch   3 Batch   53/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.608
# Epoch   3 Batch   54/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.602
# Epoch   3 Batch   55/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.608
# Epoch   3 Batch   56/134 - Train Accuracy:  0.177, Validation Accuracy:  0.179, Loss:  0.581
# Epoch   3 Batch   57/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.604
# Epoch   3 Batch   58/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.594
# Epoch   3 Batch   59/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.626
# Epoch   3 Batch   60/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.595
# Epoch   3 Batch   61/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.594
# Epoch   3 Batch   62/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.590
# Epoch   3 Batch   63/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.596
# Epoch   3 Batch   64/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.596
# Epoch   3 Batch   65/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.599
# Epoch   3 Batch   66/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.580
# Epoch   3 Batch   67/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.640
# Epoch   3 Batch   68/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.623
# Epoch   3 Batch   69/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.589
# Epoch   3 Batch   70/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.581
# Epoch   3 Batch   71/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.584
# Epoch   3 Batch   72/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.582
# Epoch   3 Batch   73/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  0.568
# Epoch   3 Batch   74/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.598
# Epoch   3 Batch   75/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.566
# Epoch   3 Batch   76/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.581
# Epoch   3 Batch   77/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.561
# Epoch   3 Batch   78/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.589
# Epoch   3 Batch   79/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.586
# Epoch   3 Batch   80/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.586
# Epoch   3 Batch   81/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.582
# Epoch   3 Batch   82/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.550
# Epoch   3 Batch   83/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.586
# Epoch   3 Batch   84/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.580
# Epoch   3 Batch   85/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.584
# Epoch   3 Batch   86/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.577
# Epoch   3 Batch   87/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.593
# Epoch   3 Batch   88/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.546
# Epoch   3 Batch   89/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.581
# Epoch   3 Batch   90/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.580
# Epoch   3 Batch   91/134 - Train Accuracy:  0.246, Validation Accuracy:  0.179, Loss:  0.506
# Epoch   3 Batch   92/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.569
# Epoch   3 Batch   93/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.563
# Epoch   3 Batch   94/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.560
# Epoch   3 Batch   95/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.571
# Epoch   3 Batch   96/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.573
# Epoch   3 Batch   97/134 - Train Accuracy:  0.138, Validation Accuracy:  0.179, Loss:  0.572
# Epoch   3 Batch   98/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.597
# Epoch   3 Batch   99/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.569
# Epoch   3 Batch  100/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.567
# Epoch   3 Batch  101/134 - Train Accuracy:  0.097, Validation Accuracy:  0.179, Loss:  0.603
# Epoch   3 Batch  102/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.559
# Epoch   3 Batch  103/134 - Train Accuracy:  0.177, Validation Accuracy:  0.179, Loss:  0.545
# Epoch   3 Batch  104/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.552
# Epoch   3 Batch  105/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.570
# Epoch   3 Batch  106/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.565
# Epoch   3 Batch  107/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  0.537
# Epoch   3 Batch  108/134 - Train Accuracy:  0.097, Validation Accuracy:  0.179, Loss:  0.589
# Epoch   3 Batch  109/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.534
# Epoch   3 Batch  110/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.551
# Epoch   3 Batch  111/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.565
# Epoch   3 Batch  112/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.552
# Epoch   3 Batch  113/134 - Train Accuracy:  0.246, Validation Accuracy:  0.179, Loss:  0.490
# Epoch   3 Batch  114/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.552
# Epoch   3 Batch  115/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.586
# Epoch   3 Batch  116/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.559
# ...
# Epoch   8 Batch   95/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.136
# Epoch   8 Batch   96/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.134
# Epoch   8 Batch   97/134 - Train Accuracy:  0.139, Validation Accuracy:  0.180, Loss:  0.133
# Epoch   8 Batch   98/134 - Train Accuracy:  0.097, Validation Accuracy:  0.179, Loss:  0.139
# Epoch   8 Batch   99/134 - Train Accuracy:  0.141, Validation Accuracy:  0.179, Loss:  0.134
# Epoch   8 Batch  100/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.135
# Epoch   8 Batch  101/134 - Train Accuracy:  0.097, Validation Accuracy:  0.179, Loss:  0.144
# Epoch   8 Batch  102/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.130
# Epoch   8 Batch  103/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.130
# Epoch   8 Batch  104/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.127
# Epoch   8 Batch  105/134 - Train Accuracy:  0.141, Validation Accuracy:  0.179, Loss:  0.135
# Epoch   8 Batch  106/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.133
# Epoch   8 Batch  107/134 - Train Accuracy:  0.180, Validation Accuracy:  0.180, Loss:  0.130
# Epoch   8 Batch  108/134 - Train Accuracy:  0.098, Validation Accuracy:  0.179, Loss:  0.135
# Epoch   8 Batch  109/134 - Train Accuracy:  0.179, Validation Accuracy:  0.180, Loss:  0.124
# Epoch   8 Batch  110/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.129
# Epoch   8 Batch  111/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.131
# Epoch   8 Batch  112/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.126
# Epoch   8 Batch  113/134 - Train Accuracy:  0.247, Validation Accuracy:  0.180, Loss:  0.116
# Epoch   8 Batch  114/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.128
# Epoch   8 Batch  115/134 - Train Accuracy:  0.097, Validation Accuracy:  0.180, Loss:  0.129
# Epoch   8 Batch  116/134 - Train Accuracy:  0.141, Validation Accuracy:  0.179, Loss:  0.130
# Epoch   8 Batch  117/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.121
# Epoch   8 Batch  118/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.126
# Epoch   8 Batch  119/134 - Train Accuracy:  0.214, Validation Accuracy:  0.179, Loss:  0.115
# Epoch   8 Batch  120/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.129
# Epoch   8 Batch  121/134 - Train Accuracy:  0.141, Validation Accuracy:  0.180, Loss:  0.121
# Epoch   8 Batch  122/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.126
# Epoch   8 Batch  123/134 - Train Accuracy:  0.141, Validation Accuracy:  0.179, Loss:  0.122
# Epoch   8 Batch  124/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  0.115
# Epoch   8 Batch  125/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.122
# Epoch   8 Batch  126/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.125
# Epoch   8 Batch  127/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  0.122
# Epoch   8 Batch  128/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.129
# Epoch   8 Batch  129/134 - Train Accuracy:  0.141, Validation Accuracy:  0.180, Loss:  0.123
# Epoch   8 Batch  130/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.122
# Epoch   8 Batch  131/134 - Train Accuracy:  0.098, Validation Accuracy:  0.179, Loss:  0.131
# Epoch   8 Batch  132/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.116
# Epoch   9 Batch    0/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.121
# Epoch   9 Batch    1/134 - Train Accuracy:  0.097, Validation Accuracy:  0.179, Loss:  0.126
# Epoch   9 Batch    2/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.118
# Epoch   9 Batch    3/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.121
# Epoch   9 Batch    4/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.118
# Epoch   9 Batch    5/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.128
# Epoch   9 Batch    6/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  0.114
# Epoch   9 Batch    7/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.118
# Epoch   9 Batch    8/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.113
# Epoch   9 Batch    9/134 - Train Accuracy:  0.180, Validation Accuracy:  0.180, Loss:  0.109
# Epoch   9 Batch   10/134 - Train Accuracy:  0.141, Validation Accuracy:  0.179, Loss:  0.123
# Epoch   9 Batch   11/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.120
# Epoch   9 Batch   12/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  0.115
# Epoch   9 Batch   13/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.120
# Epoch   9 Batch   14/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.119
# Epoch   9 Batch   15/134 - Train Accuracy:  0.139, Validation Accuracy:  0.180, Loss:  0.116
# Epoch   9 Batch   16/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.115
# Epoch   9 Batch   17/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.120
# Epoch   9 Batch   18/134 - Train Accuracy:  0.141, Validation Accuracy:  0.180, Loss:  0.119
# Epoch   9 Batch   19/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.118
# Epoch   9 Batch   20/134 - Train Accuracy:  0.178, Validation Accuracy:  0.180, Loss:  0.111
# Epoch   9 Batch   21/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.116
# Epoch   9 Batch   22/134 - Train Accuracy:  0.098, Validation Accuracy:  0.180, Loss:  0.119
# Epoch   9 Batch   23/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  0.106
# Epoch   9 Batch   24/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.123
# Epoch   9 Batch   25/134 - Train Accuracy:  0.139, Validation Accuracy:  0.180, Loss:  0.113
# Epoch   9 Batch   26/134 - Train Accuracy:  0.098, Validation Accuracy:  0.180, Loss:  0.121
# Epoch   9 Batch   27/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.115
# Epoch   9 Batch   28/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.117
# Epoch   9 Batch   29/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.101
# Epoch   9 Batch   30/134 - Train Accuracy:  0.179, Validation Accuracy:  0.180, Loss:  0.111
# Epoch   9 Batch   31/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.113
# Epoch   9 Batch   32/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  0.110
# Epoch   9 Batch   33/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.120
# Epoch   9 Batch   34/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.121
# Epoch   9 Batch   35/134 - Train Accuracy:  0.178, Validation Accuracy:  0.180, Loss:  0.118
# Epoch   9 Batch   36/134 - Train Accuracy:  0.141, Validation Accuracy:  0.179, Loss:  0.113
# Epoch   9 Batch   37/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.113
# Epoch   9 Batch   38/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.112
# Epoch   9 Batch   39/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.111
# Epoch   9 Batch   40/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.114
# Epoch   9 Batch   41/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.116
# Epoch   9 Batch   42/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.108
# Epoch   9 Batch   43/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.112
# Epoch   9 Batch   44/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.109
# Epoch   9 Batch   45/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.105
# Epoch   9 Batch   46/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.112
# Epoch   9 Batch   47/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.110
# Epoch   9 Batch   48/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.111
# Epoch   9 Batch   49/134 - Train Accuracy:  0.141, Validation Accuracy:  0.179, Loss:  0.108
# Epoch   9 Batch   50/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.113
# Epoch   9 Batch   51/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.111
# Epoch   9 Batch   52/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.106
# Epoch   9 Batch   53/134 - Train Accuracy:  0.138, Validation Accuracy:  0.180, Loss:  0.108
# Epoch   9 Batch   54/134 - Train Accuracy:  0.139, Validation Accuracy:  0.180, Loss:  0.111
# Epoch   9 Batch   55/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.113
# Epoch   9 Batch   56/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.107
# Epoch   9 Batch   57/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.110
# Epoch   9 Batch   58/134 - Train Accuracy:  0.141, Validation Accuracy:  0.179, Loss:  0.103
# Epoch   9 Batch   59/134 - Train Accuracy:  0.097, Validation Accuracy:  0.180, Loss:  0.113
# Epoch   9 Batch   60/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.104
# Epoch   9 Batch   61/134 - Train Accuracy:  0.139, Validation Accuracy:  0.180, Loss:  0.103
# Epoch   9 Batch   62/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.106
# Epoch   9 Batch   63/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.108
# Epoch   9 Batch   64/134 - Train Accuracy:  0.139, Validation Accuracy:  0.180, Loss:  0.109
# Epoch   9 Batch   65/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.109
# Epoch   9 Batch   66/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.101
# Epoch   9 Batch   67/134 - Train Accuracy:  0.096, Validation Accuracy:  0.179, Loss:  0.114
# Epoch   9 Batch   68/134 - Train Accuracy:  0.097, Validation Accuracy:  0.180, Loss:  0.111
# Epoch   9 Batch   69/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.107
# Epoch   9 Batch   70/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.105
# Epoch   9 Batch   71/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.098
# Epoch   9 Batch   72/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.103
# Epoch   9 Batch   73/134 - Train Accuracy:  0.179, Validation Accuracy:  0.180, Loss:  0.105
# Epoch   9 Batch   74/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.108
# Epoch   9 Batch   75/134 - Train Accuracy:  0.179, Validation Accuracy:  0.180, Loss:  0.103
# Epoch   9 Batch   76/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.103
# Epoch   9 Batch   77/134 - Train Accuracy:  0.178, Validation Accuracy:  0.180, Loss:  0.101
# Epoch   9 Batch   78/134 - Train Accuracy:  0.141, Validation Accuracy:  0.179, Loss:  0.101
# Epoch   9 Batch   79/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.106
# Epoch   9 Batch   80/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.102
# Epoch   9 Batch   81/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.103
# Epoch   9 Batch   82/134 - Train Accuracy:  0.179, Validation Accuracy:  0.180, Loss:  0.097
# Epoch   9 Batch   83/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.104
# Epoch   9 Batch   84/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.104
# Epoch   9 Batch   85/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.103
# Epoch   9 Batch   86/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.101
# Epoch   9 Batch   87/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.110
# Epoch   9 Batch   88/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  0.095
# Epoch   9 Batch   89/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.102
# Epoch   9 Batch   90/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.106
# Epoch   9 Batch   91/134 - Train Accuracy:  0.247, Validation Accuracy:  0.180, Loss:  0.086
# Epoch   9 Batch   92/134 - Train Accuracy:  0.141, Validation Accuracy:  0.180, Loss:  0.097
# Epoch   9 Batch   93/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.097
# Epoch   9 Batch   94/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.094
# Epoch   9 Batch   95/134 - Train Accuracy:  0.139, Validation Accuracy:  0.180, Loss:  0.101
# Epoch   9 Batch   96/134 - Train Accuracy:  0.139, Validation Accuracy:  0.180, Loss:  0.100
# Epoch   9 Batch   97/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.099
# Epoch   9 Batch   98/134 - Train Accuracy:  0.097, Validation Accuracy:  0.180, Loss:  0.102
# Epoch   9 Batch   99/134 - Train Accuracy:  0.141, Validation Accuracy:  0.179, Loss:  0.101
# Epoch   9 Batch  100/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.100
# Epoch   9 Batch  101/134 - Train Accuracy:  0.098, Validation Accuracy:  0.179, Loss:  0.107
# Epoch   9 Batch  102/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.098
# Epoch   9 Batch  103/134 - Train Accuracy:  0.178, Validation Accuracy:  0.179, Loss:  0.098
# Epoch   9 Batch  104/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.094
# Epoch   9 Batch  105/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.104
# Epoch   9 Batch  106/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.101
# Epoch   9 Batch  107/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  0.099
# Epoch   9 Batch  108/134 - Train Accuracy:  0.097, Validation Accuracy:  0.180, Loss:  0.102
# Epoch   9 Batch  109/134 - Train Accuracy:  0.179, Validation Accuracy:  0.180, Loss:  0.095
# Epoch   9 Batch  110/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.098
# Epoch   9 Batch  111/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.100
# Epoch   9 Batch  112/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.096
# Epoch   9 Batch  113/134 - Train Accuracy:  0.247, Validation Accuracy:  0.180, Loss:  0.091
# Epoch   9 Batch  114/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.098
# Epoch   9 Batch  115/134 - Train Accuracy:  0.097, Validation Accuracy:  0.179, Loss:  0.098
# Epoch   9 Batch  116/134 - Train Accuracy:  0.141, Validation Accuracy:  0.179, Loss:  0.099
# Epoch   9 Batch  117/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.092
# Epoch   9 Batch  118/134 - Train Accuracy:  0.139, Validation Accuracy:  0.180, Loss:  0.097
# Epoch   9 Batch  119/134 - Train Accuracy:  0.214, Validation Accuracy:  0.180, Loss:  0.088
# Epoch   9 Batch  120/134 - Train Accuracy:  0.139, Validation Accuracy:  0.180, Loss:  0.101
# Epoch   9 Batch  121/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.091
# Epoch   9 Batch  122/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.098
# Epoch   9 Batch  123/134 - Train Accuracy:  0.141, Validation Accuracy:  0.179, Loss:  0.092
# Epoch   9 Batch  124/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  0.088
# Epoch   9 Batch  125/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.092
# Epoch   9 Batch  126/134 - Train Accuracy:  0.140, Validation Accuracy:  0.179, Loss:  0.095
# Epoch   9 Batch  127/134 - Train Accuracy:  0.179, Validation Accuracy:  0.179, Loss:  0.093
# Epoch   9 Batch  128/134 - Train Accuracy:  0.139, Validation Accuracy:  0.179, Loss:  0.098
# Epoch   9 Batch  129/134 - Train Accuracy:  0.141, Validation Accuracy:  0.180, Loss:  0.095
# Epoch   9 Batch  130/134 - Train Accuracy:  0.139, Validation Accuracy:  0.180, Loss:  0.093
# Epoch   9 Batch  131/134 - Train Accuracy:  0.098, Validation Accuracy:  0.179, Loss:  0.100
# Epoch   9 Batch  132/134 - Train Accuracy:  0.140, Validation Accuracy:  0.180, Loss:  0.087
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    return [vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in sentence.lower().split()]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# Input
#   Word Ids:      [129, 107, 196, 174, 31, 199, 124]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [281, 68, 40, 275, 341, 303, 354, 254, 56, 205, 205, 205, 247, 247, 247, 247, 247, 247]
#   French Words: ['voulez', 'et', 'mangue', 'envisage', 'est-ce', 'octobre', 'california', 'relaxant', 'du', 'bleue', 'bleue', 'bleue', "l'oiseau", "l'oiseau", "l'oiseau", "l'oiseau", "l'oiseau", "l'oiseau"]

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
